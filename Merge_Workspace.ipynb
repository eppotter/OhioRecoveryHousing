# %%
from mcm_orh_functions import *
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import inspect


import warnings
warnings.filterwarnings("ignore")


orh_data = pd.read_csv('./orh_2022.csv')

orh_data = format_orh(orh_data)

orh_hist = pd.read_csv('./orh_v1.csv')

def format_orh_cols(input_data, column_path):

    orh_columns = pd.read_csv(column_path)

    orh_columns = orh_columns['Columns'].tolist()

    input_data.columns = orh_columns

    return input_data

old_col_new = './old_col_update.csv'

orh_hist = format_orh_cols(old_version, old_col_new)

orh_hist = orh_hist[orh_hist.columns[8:]]


new_survey = orh_data[['input_type', 'Stage', 'org_house_name', 'mother_first_i', 'father_first_i', 'age', 'highest_education_degree',
                       'curr_status_cjs_parole_probation', 'curr_status_cjs_drug_court', 'curr_status_cjs_no_involvement','curr_status_cjs_no_answer',
                       'parent', 'gender_identify_agender', 'gender_identify_genderqueer', 'gender_identify_gender_fluid', 'gender_identify_man',
                       'gender_identify_non-binary', 'gender_identify_questioning', 'gender_identify_transgender','gender_identify_trans_man',
                       'gender_identify_trans_woman', 'gender_identify_woman', 'gender_identify_no_answer', 'gender_identify_other',
                       'sexual_identity_asexual', 'sexual_identity_bisexual', 'sexual_identity_gay', 'sexual_identity_lesbian',
                       'sexual_identity_pansexual', 'sexual_identity_queer', 'sexual_identity_same_gender_loving', 'sexual_identity_other',
                       'sexual_identity_heterosexual', 'sexual_identity_no_answer', 'sexual_identity_questioning', 'race_id_white',
                       'race_id_black_or_african_american', 'race_id_american_indian_or_alaska_native', 'race_id_chinese', 'race_id_vietnamese',
                       'race_id_native_hawaiian', 'race_id_filipino', 'race_id_korean', 'race_id_samoan', 'race_id_asian_indian', 'race_id_japanese',
                       'race_id_chamorro', 'race_id_other_asian', 'race_id_other_pacific_islander', 'rad_id_no_answer', 'race_id_other',
                       'last_30_alcohol_use', 'last_30_illegal_drugs_non_prescribed_medications', 'last_30_attendance_12_step',
                       'last_30_attendance_organized_religious_group', 'last_30_attendance_other_support_group', 'last_30_attendance_sober_support_outing',
                       'last_30_attendance_activities_sponsored_by_recovery_residence', 'last_30_attendance_activities_provided_while_incarcerated',
                       'last_30_attendance_none', 'last_30_attendance_no_answer', 'doc_status_drivers_license', 'doc_status_state_id', 
                       'doc_status_social_security_card', 'doc_status_birth_certificate', 'last_30_education_progress_ged',
                       'last_30_education_progress_vocational_school', 'last_30_education_progress_skilled_training', 'last_30_education_progress_college',
                       'last_30_education_progress_not_involved', 'last_30_employment_status', 'last_30_volunteering_status',  'last_30_physical_health',
                       'last_30_mental_health', 'last_30_substance_use_consequences_social', 'last_30_substance_use_consequences_health_behavioral',
                       'last_30_substance_use_consequences_financial', 'last_30_substance_use_consequences_none_of_above', 
                       'last_30_substance_use_consequences_no_answer', 'last_30_substance_use_consequences_other', 
                       'move_out_statement_i_have_people_in_my_life_i_can_rely_on_in_support_of_my_recovery',
                       'move_out_statement_i_have_goals_and_hopes_for_my_future',
                       'move_out_statement_i_have_problem-solving_skills_and_resources_to_help_me_make_healthy_decisions',
                       'move_out_statement_i_have_a_clear_sense_of_who_i_am',
                       'move_out_statement_i_have_meaningful_positive_participation_in_my_family_and_community',
                       'move_out_statement_i_have_a_sense_of_purpose_in_my_life',
                       'move_out_statement_i_have_a_sense_of_personal_values_that_guide_me_between_right_and_wrong',
                       'move_out_statement_i_have_a_sense_of_community_and_belonging', 'move_out_recovery_housing_success',
                       'move_out_recovery_housing_leave_reason', 'last_30_attendance_working_with_sponsor','move_out_recovery_housing_stay_time_period']]


old_survey = orh_hist[['frm_completion_stage',
'org_house_name',
'your_first_i',
'your_last_i',
'year_of_birth',
'highest_education_degree',
'curr_status_cjs_parole_probation',
'curr_status_cjs_drug_court',
'curr_status_cjs_arrest',
'curr_status_cjs_completed_requirements',
'curr_status_cjs_no_involvement',
'curr_status_cjs_no_answer',
'parent',
'gender_identity_free_form_answer',
'race_id_white',
'race_id_black_or_african_american',
'race_id_american_indian_or_alaska_native',
'race_id_asian_v1',
'race_id_native_hawaiian',
'race_id_latino',
'rad_id_no_answer',
'last_30_alcohol_use_any',
'last_30_alcohol_use_to_intox',
'last_30_illegal_drugs_non_prescribed_medications',
'last_30_alcohol_use_and_drug',
'last_30_attendance_12_step',
'last_30_attendance_organized_religious_group',
'last_30_attendance_other_support_group',
'last_30_attendance_sober_support_outing',
'last_30_attendance_activities_sponsored_by_recovery_residence',
'last_30_attendance_activities_provided_while_incarcerated',
'last_30_attendance_none',
'last_30_attendance_no_answer',
'last_30_attendance_in_home_group',
'doc_status_drivers_license_yes',
'doc_status_drivers_license_no',
'doc_status_drivers_license_susp',
'doc_status_drivers_license_rev',
'doc_status_drivers_license_no_answer',
'doc_status_state_id',
'doc_status_social_security_card',
'doc_status_birth_certificate',
'last_30_education_progress_ged',
'last_30_education_progress_vocational_school',
'last_30_education_progress_skilled_training',
'last_30_education_progress_college',
'last_30_education_progress_not_involved',
'last_30_employment_status_full_time',
'last_30_employment_status_part_time',
'last_30_employment_status_temp_assignment',
'last_30_employment_status_searching',
'last_30_employment_status_retired',
'last_30_employment_status_disabled_not_receiving_benefits',
'last_30_employment_status_disabled_receiving_benefits',
'last_30_employment_status_not_searching',
'last_30_employment_status_working_where_incarcerated',
'last_30_employment_status_unable_to_work_while_incarcerated',
'last_30_volunteering_status_less_than_10_hrs',
'last_30_volunteering_status_more_than_10_hrs',
'last_30_employment_volunteering_no_answer',
'last_30_employment_volunteering_other',
'last_30_physical_health',
'last_30_mental_health',
'last_30_substance_use_consequences_social',
'last_30_substance_use_consequences_health_behavioral',
'last_30_substance_use_consequences_financial',
'last_30_substance_use_consequences_none_of_above',
'last_30_substance_use_consequences_no_answer',
'last_30_substance_use_consequences_other',
'move_out_statement_i_have_people_in_my_life_i_can_rely_on_in_support_of_my_recovery',
'move_out_statement_i_have_goals_and_hopes_for_my_future',
'move_out_statement_i_have_problem-solving_skills_and_resources_to_help_me_make_healthy_decisions',
'move_out_statement_i_have_a_clear_sense_of_who_i_am',
'move_out_statement_i_have_meaningful_positive_participation_in_my_family_and_community',
'move_out_statement_i_have_a_sense_of_purpose_in_my_life',
'move_out_statement_i_have_a_sense_of_personal_values_that_guide_me_between_right_and_wrong',
'move_out_statement_i_have_a_sense_of_community_and_belonging',
'last_30_attendance_working_with_sponsor',
'move_in_date',
'move_out_date']]

import numpy as np

# input_type and stage


old_survey = old_survey[old_survey['frm_completion_stage'].notna()]

old_survey.insert(0, 'input_type', ['Staff' if 'without notice' in desc else 'Client' for desc in old_survey['frm_completion_stage']])

mask_in = old_survey['frm_completion_stage'].str.contains('This form is being completed as a part of MOVE-IN to this recovery home, and I recently moved-in.')
mask_out = old_survey['frm_completion_stage'].str.contains('This form is being completed as a part of MOVE-OUT from this recovery home.')
mask_follow = old_survey['frm_completion_stage'].str.contains('This form is being completed as part of an IN-HOUSE FOLLOW-UP SIX MONTHS after move-in')
mask_agent = old_survey['frm_completion_stage'].str.contains('I am completing this form for a resident who moved out without notice.')

    
in_new = 'Move In'
out_new = 'Move Out'
follow_new = 'Follow Up'
out_agent_new = 'Move Out'

old_survey.loc[mask_in,
                   'frm_completion_stage'] = in_new
old_survey.loc[mask_out,
                   'frm_completion_stage'] = out_new
old_survey.loc[mask_agent,
                   'frm_completion_stage'] = out_agent_new
old_survey.loc[mask_follow,
                   'frm_completion_stage'] = follow_new

old_survey = old_survey.rename(columns={'frm_completion_stage': 'Stage'})

new_survey['org_house_name'] = new_survey['org_house_name'].str.title()
old_survey['org_house_name'] = old_survey['org_house_name'].str.title()

new_survey['mother_first_i'] = new_survey['mother_first_i'].str.title()
old_survey['your_first_i'] = old_survey['your_first_i'].str.title()

new_survey['father_first_i'] = new_survey['father_first_i'].str.title()
old_survey['your_last_i'] = old_survey['your_last_i'].str.title()

#Adjust Year for DOB


# NEED TO ADJUST TO MAKE REASONABLE AGE RANGES

def modify_year(year):
    if isinstance(year, int) and 1923 <= year <= 2005:
        return year
    else:
        return 'Unknown'

# Apply the custom function to modify the 'Year' column

old_survey['year_of_birth'] = pd.to_numeric(old_survey['year_of_birth'], errors='coerce').astype(pd.Int64Dtype())

old_survey ['year_of_birth'] = old_survey['year_of_birth'].apply(modify_year)

old_survey.loc[old_survey['year_of_birth'] != 'Unknown', 'year_of_birth'] = 2023 - old_survey.loc[old_survey['year_of_birth'] != 'Unknown', 'year_of_birth']


# Define the age categories
age_bins = [18, 24, 29, 34, 39, 44, 49, 54, 59, 64, 69, 100]  # Customize as per your requirement
age_labels = ['18-24 years', '25-29 years', '30-34 years', '35-39 years', '40-44 years', '45-49 years', '50-54 years', '55-59 years', '60-64 years', '65-69 years', '70+ years']

# Create a new column 'age_category' with the age categories
old_survey.loc[old_survey['year_of_birth'] != 'Unknown', 'year_of_birth'] = pd.cut(old_survey.loc[old_survey['year_of_birth'] != 'Unknown', 'year_of_birth'], 
                                                                                   bins = age_bins, 
                                                                                   labels = age_labels, 
                                                                                   right=False)


# CJS Status

new_survey['CJS'] = ((new_survey['curr_status_cjs_parole_probation'].notnull() | new_survey['curr_status_cjs_drug_court'].notnull()) & new_survey['curr_status_cjs_no_involvement'].isnull()).astype(int)
new_survey['No_CJS'] = (new_survey['curr_status_cjs_no_involvement'].notnull() & new_survey['curr_status_cjs_parole_probation'].isnull() & new_survey['curr_status_cjs_drug_court'].isnull()).astype(int)

old_survey['CJS'] = ((old_survey['curr_status_cjs_parole_probation'].notnull() | old_survey['curr_status_cjs_drug_court'].notnull() | old_survey['curr_status_cjs_arrest'].notnull() | old_survey['curr_status_cjs_completed_requirements'].notnull()) & old_survey['curr_status_cjs_no_involvement'].isnull()).astype(int)
old_survey['No_CJS'] = (old_survey['curr_status_cjs_no_involvement'].notnull() & old_survey['curr_status_cjs_parole_probation'].isnull() & old_survey['curr_status_cjs_completed_requirements'].isnull() & old_survey['curr_status_cjs_arrest'].isnull() & old_survey['curr_status_cjs_drug_court'].isnull()).astype(int)

# %%
# Out:
# 30-34 years    2393
# 35-39 years    2223
# 40-44 years    1859
# 45-49 years    1236
# 25-29 years    1150
# 50-54 years     832
# 55-59 years     656
# 60-64 years     520
# 18-24 years     242
# 65-69 years     241
# Unknown         221
# 70+ years        78
# Name: year_of_birth, dtype: int64

# %%
# Column Checker

col = 7

print("Old Survey")
print(old_survey[old_survey.columns[col]])
print("/n/n")

print("New Survey")
print(new_survey[new_survey.columns[col]])
# Out:
# Old Survey
# 0        Currently on parole/probation
# 1                                  NaN
# 2                                  NaN
# 3        Currently on parole/probation
# 4                                  NaN
#                      ...
# 11760                              NaN
# 11761                              NaN
# 11762                              NaN
# 11763                              NaN
# 11764    Currently on parole/probation
# Name: curr_status_cjs_parole_probation, Length: 11651, dtype: object
# /n/n
# New Survey
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3       Currently on parole/probation
# 4                                 NaN
#                     ...
# 4125    Currently on parole/probation
# 4126    Currently on parole/probation
# 4127    Currently on parole/probation
# 4128    Currently on parole/probation
# 4129                              NaN
# ...

# %%
# EDUCATION
#old_survey['highest_education_degree'].value_counts()
#new_survey['highest_education_degree'].value_counts()

# WAY TOO MANY EDUCATIONAL OPTIONS - LET'S HOLD OFF FOR NOW


new_survey['CJS'] = ((new_survey['curr_status_cjs_parole_probation'].notnull() | new_survey['curr_status_cjs_drug_court'].notnull()) & new_survey['curr_status_cjs_no_involvement'].isnull()).astype(int)
new_survey['No_CJS'] = (new_survey['curr_status_cjs_no_involvement'].notnull() & new_survey['curr_status_cjs_parole_probation'].isnull() & new_survey['curr_status_cjs_drug_court'].isnull()).astype(int)
# Create 'No_CJS' column

# Create 'CJS' column
old_survey['CJS'] = ((old_survey['curr_status_cjs_parole_probation'].notnull() | old_survey['curr_status_cjs_drug_court'].notnull() | old_survey['curr_status_cjs_arrest'].notnull() | old_survey['curr_status_cjs_completed_requirements'].notnull()) & old_survey['curr_status_cjs_no_involvement'].isnull()).astype(int)

# Create 'No_CJS' column
old_survey['No_CJS'] = (old_survey['curr_status_cjs_no_involvement'].notnull() & old_survey['curr_status_cjs_parole_probation'].isnull() & old_survey['curr_status_cjs_completed_requirements'].isnull() & old_survey['curr_status_cjs_arrest'].isnull() & old_survey['curr_status_cjs_drug_court'].isnull()).astype(int)

#High school diploma or equivalency (GED)
#No degree received                      
#Associate degree                        
#Technical or vocational certification   
#Bachelor's degree                       
#Prefer not to answer                    
#Unknown                                 
#Master's degree or beyond

# %%
new_survey.head()
# Out:
#   input_type      Stage                       org_house_name mother_first_i  \
# 0     Client  Follow Up  12 Step Life: The Ethel Hardy House              N
# 1     Client  Follow Up  12 Step Life: The Ethel Hardy House              N
# 2     Client  Follow Up  12 Step Life: The Ethel Hardy House              L
# 3     Client  Follow Up  12 Step Life: The Ethel Hardy House              V
# 4     Client  Follow Up  12 Step Life: The Ethel Hardy House              L
#
#   father_first_i          age                  highest_education_degree  \
# 0              D  18-24 years                                       NaN
# 1              D  18-24 years                                       NaN
# 2              W  60-64 years  High school diploma or equivalency (GED)
# 3              T  35-39 years  High school diploma or equivalency (GED)
# 4              W  60-64 years                        No degree received
#
#   curr_status_cjs_parole_probation curr_status_cjs_drug_court  \
# ...
